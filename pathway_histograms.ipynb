# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sb
from data_parsing_class import DataParser
from class_test import LSTM
from preprocessing import DataGenerator

# %%
#dataLaaL = DataParser('course_data/MITxPRO+LASERxB1+1T2019/LaaL', 'course_data/MITxPRO+LASERxB1+1T2019/MITxPRO-LASERxB1-1T2019-auth_user-students.csv')
dataAM = DataParser('course_data/MITxPRO+AMxB+1T2018/edges', 'course_data/MITxPRO+AMxB+1T2018/MITxPRO-AMxB-1T2018-auth_user-students.csv')

# %%
sb.set(context='notebook', style='white', palette='deep', font='Times', font_scale=1, color_codes=True, rc=None)

#traj_lengths = dataLaaL.trajectories.map(len).values
traj_lengths = dataAM.trajectories.map(len).values
sb.distplot(traj_lengths, kde=False)
print("Maximum trajectory identified by number of clicks: ", max(traj_lengths))
plt.title('LaaL course')
plt.xlabel('Learner pathway length identified by number of clicks')
plt.ylabel('Count of students')
# Out:
# Maximum trajectory identified by number of clicks:  3483
# Text(0, 0.5, 'Count of students')
